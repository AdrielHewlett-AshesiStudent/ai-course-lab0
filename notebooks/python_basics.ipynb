# %% [markdown]
# **PYTHON BASICS FILE**

# %%
Lowest

# %%
list=["A","C","D","E","F","D"]
lowest=list[0]
for i in list:
  if i<lowest:
    lowest=i
print("The lowest is "+lowest)
# Out:
# The lowest is A

# %%
Greatest

# %%
list=["A","C","D","E","F","D"]
greatest=list[0]
for i in list:
  if i>greatest:
    greatest=i
print("The greatest is "+greatest)
# Out:
# The greatest is F
